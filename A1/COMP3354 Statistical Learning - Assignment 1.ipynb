# %% [markdown]
#                                Rohak Singhal, 3035242475

# %% [markdown]
# ## Question 1

# %%
set.seed(2475)

# %% [markdown]
# ### (a)

# %%
x = rnorm(100)

# %%
print(x)
# Out:
#   [1]  0.17581566 -0.85333388 -0.07059335 -2.10899960 -0.51240497 -1.99360400
#   [7]  1.20137416  0.46939682 -1.12695202 -0.04882572 -1.30997098  0.37741353
#  [13] -1.06160646 -0.24703378 -1.15554868  1.30176982  0.24287263 -1.47877834
#  [19]  1.86821012  1.40682505 -1.09345844 -1.25221796  2.03757657 -1.04506729
#  [25] -0.59585903 -0.57325150 -0.95593438  0.24508638  0.00938404 -0.07967405
#  [31]  1.00599096 -0.54341051  0.74580229 -0.36316567  1.35307892 -0.58298037
#  [37] -0.29184703  1.08636359 -0.11454881  0.37152496  1.07170526 -0.05115812
#  [43]  1.06212874 -1.50193598  1.25673484  0.11295655  1.34839561 -1.18353751
#  [49] -0.12587590  0.10475345  0.83205511 -0.14976541  0.05447357 -1.50924815
#  [55]  0.10016036  0.94541970  0.35456148 -1.18958270 -1.34154180 -0.06864488
#  [61]  0.16934335  0.40773750  1.01796790  0.77187211 -0.14240069  0.80259124
#  [67]  1.17473896 -1.21294884 -0.01804750 -1.60357285 -2.08146443  1.22746809
# ...

# %% [markdown]
# ### (b)

# %%
eps = rnorm(100,sd = 0.25)

# %%
print(eps)
# Out:
#   [1]  0.108729781 -0.190217536 -0.468208861 -0.230432472 -0.284655943
#   [6] -0.023264915 -0.219719208 -0.288729836  0.058413463  0.602783746
#  [11]  0.060530489 -0.111060535  0.195802571 -0.165481837  0.270719458
#  [16] -0.057693230 -0.135895977  0.132653626 -0.158473442 -0.080220906
#  [21]  0.098508312 -0.188378504  0.439415698  0.022030203  0.426916759
#  [26] -0.235171774 -0.145247728  0.238340850  0.218217098 -0.523329453
#  [31]  0.031322474 -0.039824255  0.260431721  0.275393051  0.014276955
#  [36] -0.181953650 -0.081108754  0.258251033  0.179496165 -0.129559117
#  [41] -0.033890878  0.021140729  0.038261151 -0.461011775  0.196965572
#  [46]  0.265441889 -0.065748551 -0.270770830  0.256793369  0.103289390
#  [51]  0.274582266  0.192505230  0.113416836 -0.113668040  0.418192517
#  [56] -0.319864772 -0.102336953  0.003507871  0.017751375  0.170713792
#  [61] -0.020250942  0.294108884 -0.114781100 -0.071395859 -0.119778129
# ...

# %% [markdown]
# ### (c)

# %%
y = -1+0.5*x+eps

# %%
print(y)
# Out:
#   [1] -0.80336239 -1.61688448 -1.50350554 -2.28493227 -1.54085843 -2.02006691
#   [7] -0.61903213 -1.05403143 -1.50506255 -0.42162911 -1.59445500 -0.92235377
#  [13] -1.33500066 -1.28899873 -1.30705488 -0.40680832 -1.01445966 -1.60673554
#  [19] -0.22436838 -0.37680838 -1.44822091 -1.81448749  0.45820398 -1.50050344
#  [25] -0.87101275 -1.52179752 -1.62321492 -0.63911596 -0.77709088 -1.56316648
#  [31] -0.46568205 -1.31152951 -0.36666714 -0.90618978 -0.30918358 -1.47344383
#  [37] -1.22703227 -0.19856717 -0.87777824 -0.94379664 -0.49803825 -1.00443833
#  [43] -0.43067448 -2.21197976 -0.17466701 -0.67807984 -0.39155075 -1.86253958
#  [49] -0.80614458 -0.84433388 -0.30939018 -0.88237748 -0.85934638 -1.86829211
#  [55] -0.53172730 -0.84715492 -0.92505621 -1.59128348 -1.65301952 -0.86360865
#  [61] -0.93557927 -0.50202236 -0.60579715 -0.68545980 -1.19097847 -0.81504669
#  [67] -0.25853778 -1.50211845 -1.30055710 -1.86627220 -1.93076069 -0.51194821
# ...

# %%
length(y)
# Out:
# [1] 100

# %% [markdown]
# Length of y is 100, β0 = -1 and β1 = 0.5

# %% [markdown]
# ### (d)

# %%
plot(x,y)
# Out:
# plot without title

# %% [markdown]
# My observation is that the data is mostly linearly related with some amount of added noise.

# %%
# plot(x,1:100); plot(eps,1:100)

# %% [markdown]
# ### (e)

# %%
lm.fit=lm(y~x)

# %%
print(lm.fit)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#      -1.017        0.501

# %% [markdown]
# βˆ0 = -1.017 and βˆ1 = 0.501 whereas β0 = 1 and β1 = 0.5. The coefficients are nearly equal.

# %%
# summary(lm.fit)

# %% [markdown]
# ### (f)

# %%
plot(x,y)
abline(lm.fit, col='red', lty=2)
abline(-1,0.5, col='blue', lty=2)
legend(x = 'topleft', legend=c("Line 1", "Line 2"),col=c("red", "blue"), lty=2, cex=0.8)
# Out:
# plot without title

# %% [markdown]
# ### (g)

# %%
lm.fit2=lm(y~x+I(x**2))

# %%
print(lm.fit2)
# Out:
# Call:
# lm(formula = y ~ x + I(x^2))
#
# Coefficients:
# (Intercept)            x       I(x^2)
#   -1.011590     0.501941    -0.005204

# %%
summary(lm.fit2)
summary(lm.fit)
# Out:
# Call:
# lm(formula = y ~ x + I(x^2))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.51155 -0.14447 -0.03102  0.17562  0.61448
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.011590   0.028812 -35.110   <2e-16 ***
# x            0.501941   0.022599  22.211   <2e-16 ***
# I(x^2)      -0.005204   0.015918  -0.327    0.744
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2323 on 97 degrees of freedom
# Multiple R-squared:  0.8376,	Adjusted R-squared:  0.8342
# F-statistic: 250.1 on 2 and 97 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.50611 -0.14438 -0.03067  0.18119  0.61998
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.01714    0.02316  -43.91   <2e-16 ***
# x            0.50097    0.02230   22.47   <2e-16 ***
# ---
# ...

# %% [markdown]
# ** Is there evidence that the quadratic term improves the model fit? **

# %% [markdown]
# ### (h)

# %%
eps_less = rnorm(100,sd = 0.1)
y_less = -1+0.5*x+eps_less

# %%
plot(x,y_less)
# Out:
# plot without title

# %%
lm.fit_less=lm(y_less~x)
print(lm.fit_less)
# Out:
# Call:
# lm(formula = y_less ~ x)
#
# Coefficients:
# (Intercept)            x
#     -1.0021       0.4995

# %%
plot(x,y_less)
abline(lm.fit_less, col='red', lty=2)
abline(-1,0.5, col='blue', lty=2)
legend(x = 'topleft', legend=c("Line 1", "Line 2"),col=c("red", "blue"), lty=2, cex=0.8)
# Out:
# plot without title

# %% [markdown]
# ** Describe your results. **

# %% [markdown]
# ### (i)

# %%
eps_more = rnorm(100,sd = 0.5)
y_more = -1+0.5*x+eps_more

# %%
plot(x,y_more)
# Out:
# plot without title

# %%
lm.fit_more=lm(y_more~x)
print(lm.fit_more)
# Out:
# Call:
# lm(formula = y_more ~ x)
#
# Coefficients:
# (Intercept)            x
#     -0.9585       0.5487

# %%
plot(x,y_more)
abline(lm.fit_more, col='red', lty=2)
abline(-1,0.5, col='blue', lty=2)
legend(x = 'topleft', legend=c("Line 1", "Line 2"),col=c("red", "blue"), lty=2, cex=0.8)
# Out:
# plot without title

# %% [markdown]
# ** Describe your results. **

# %% [markdown]
# ### (j)

# %% [markdown]
# ** What are the confidence intervals for β0 and β1 based on the original data set, the noisier data
# set, and the less noisy data set? **

# %%
# summary(lm.fit)

# %%
# summary(lm.fit_more)

# %%
# summary(lm.fit_less)

# %%
confint (lm.fit)
# Out:
#             2.5 %      97.5 %
# (Intercept) -1.0631133 -0.9711758
# x            0.4567151  0.5452175

# %%
confint (lm.fit_more)
# Out:
#             2.5 %      97.5 %
# (Intercept) -1.0544615 -0.862509
# x            0.4563346  0.641115

# %%
confint (lm.fit_less)
# Out:
#             2.5 %      97.5 %
# (Intercept) -1.0224996 -0.9816347
# x            0.4798477  0.5191858

# %% [markdown]
# ** Comment on your results. **
